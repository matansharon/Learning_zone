# %%
import requests
url="https://api.fda.gov/device/classification.json?search=product_class=Stopcock, I.V."
res=requests.get(url)

# %%
res.json()
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2024-04-15',
#   'results': {'skip': 0, 'limit': 1, 'total': 6}},
#  'results': [{'third_party_flag': 'Y',
#    'life_sustain_support_flag': 'N',
#    'gmp_exempt_flag': 'N',
#    'summary_malfunction_reporting': 'Eligible',
#    'product_code': 'LHI',
#    'openfda': {'k_number': ['K955398',
#      'K213513',
#      'K924064',
#      'K970359',
#      'K023747',
#      'K080976',
#      'K853212',
#      'K860434',
#      'K152441',
#      'K001368',
#      'K132863',
#      'K024239',
#      'K905201',
#      'K060866',
#      'K853075',
#      'K101309',
#      'K190149',
# ...

# %%
import requests

def query_fda_for_device(api_key, device_name, limit=10):
    """
    Fetches device event data from openFDA for a specified device name.
    
    Args:
    - api_key (str): Your API key for accessing openFDA.
    - device_name (str): Name of the device to search for.
    - limit (int): Number of results to return.

    Returns:
    - dict: JSON response containing device event data.
    """
    base_url = "https://api.fda.gov/device/event.json"
    query_params = {
        'search': f'device.generic_name:{device_name}',
        'limit': limit
    }
    response = requests.get(base_url, headers={'Content-Type': 'application/json'}, params=query_params)
    if response.status_code == 200:
        return response.json()  # Returns the parsed JSON response
    else:
        return response.status_code, response.text

# %%
# Usage
api_key = 'YOUR_API_KEY'  # Replace with your actual API key
device_name = '"Stopcock, I.V. Set"'
data = query_fda_for_device(api_key, device_name, limit=5)
print(data)
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2024-04-10', 'results': {'skip': 0, 'limit': 5, 'total': 2037}}, 'results': [{'manufacturer_contact_zip_ext': '', 'manufacturer_g1_address_2': '', 'event_location': 'I', 'report_to_fda': '*', 'manufacturer_contact_t_name': '', 'manufacturer_contact_state': 'IL', 'manufacturer_link_flag': 'Y', 'manufacturer_contact_address_2': '', 'manufacturer_g1_city': '', 'manufacturer_contact_address_1': '600 N. FIELD DR.', 'manufacturer_contact_pcity': '22470623', 'event_type': 'Malfunction', 'report_number': '9617594-2020-00129', 'type_of_report': ['Initial submission'], 'product_problem_flag': 'Y', 'date_rece
# ...

# %%
item=enumerate(data['results'])
for key,value in item:
    print(key,value)
# Out:
# 0 {'manufacturer_contact_zip_ext': '', 'manufacturer_g1_address_2': '', 'event_location': 'I', 'report_to_fda': '*', 'manufacturer_contact_t_name': '', 'manufacturer_contact_state': 'IL', 'manufacturer_link_flag': 'Y', 'manufacturer_contact_address_2': '', 'manufacturer_g1_city': '', 'manufacturer_contact_address_1': '600 N. FIELD DR.', 'manufacturer_contact_pcity': '22470623', 'event_type': 'Malfunction', 'report_number': '9617594-2020-00129', 'type_of_report': ['Initial submission'], 'product_problem_flag': 'Y', 'date_received': '20200504', 'manufacturer_address_2': '', 'pma_pmn_number': 'K964435', 'date_of_event': '20200217', 'reprocessed_and_reused_flag': 'N', 'manufacturer_address_1': '', 'exemption_number': '', 'manufacturer_contact_zip_code': '60045', 'reporter_occupation_code': 'NURSE', 'manufacturer_contact_plocal': '2247062300', 'noe_summarized': '1', 'manufacturer_contact_l_name': 'ZANONI', 'source_type': ['COMPANY REPRESENTATIVE', 'DISTRI'], 'distributor_zip_code_ext': ''
# ...
